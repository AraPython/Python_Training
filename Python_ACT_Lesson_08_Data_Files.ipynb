# %% [markdown]
# #**File Handling in Python**
#
# Working of open() function
# ```
# f = open(filename, mode)
# ```
# r: open an existing file for a read operation.
#
# w: open an existing file for a write operation. If the file already contains some data then it will be overridden.
#
# a:  open an existing file for append operation. It won’t override existing data.
#
# r+:  To read and write data into the file. The previous data in the file will be overridden.
#
# w+: To write and read data. It will override existing data.
#
# a+: To append and read data from the file. It won’t override existing data.
# ```
# # a file named "geek", will be opened with the reading mode.
# file = open('geek.txt', 'r')
# # This will print every line one by one in the file
# for each in file:
# 	print (each)
# ```

# %%
# a file named "geek", will be opened with the reading mode.
file = open('/content/file.txt', 'r')
# This will print every line one by one in the file
for line in file:
    print (line)
# Out:
# test data
#
# test data
#
# hhh
#
# hhhhhh
#
# hhh

# %% [markdown]
# # **Working of read() mode**
#
#
# ```
#  file.read().
# ```
#
#
# ```
# # Python code to illustrate read() mode
# file = open("file.txt", "r")
# print (file.read())
#
# ```

# %%
file = open("/test.txt", "r")
print (file.read())
# Out:
# t
# t
# t
# t
# t
# t
# t
# tt
#
# t

# %% [markdown]
# # **Creating a file using write() mode**
#
#
# ```
# # Python code to create a file
# file = open('geek.txt','w')
# file.write("This is the write command")
# file.write("It allows us to write in a particular file")
# file.close()
#
# ```

# %%
file = open('/content/drive/MyDrive/Act/Python Pogramming/ACT_Python_Test.txt','w')
file.write("This is the write command")
file.write("It allows us to write in a particular file")
file.write("dfsdfasdfasdfasdfafd")
file.close()

# %% [markdown]
# # **Working of append() mode**
#
#
# ```
# # Python code to illustrate append() mode
# file = open('geek.txt','a')
# file.write("This will add this line")
# file.close()
#
# ```

# %%
# Python code to illustrate append() mode
file = open('ACT_Python_Test.txt','a')
for i in range(5):
  file.write(f"\nThis will add this line{i}")
file.close()

# %% [markdown]
# # **Using write along with the with() function**
#
#
# ```
# # Python code to illustrate with()
# with open("file.txt") as file:
# 	data = file.read()
# # do something with data
#
# ```
#
#
# ```
# # Python code to illustrate with() alongwith write()
# with open("file.txt", "w") as f:
# 	f.write("Hello World!!!")
# ```

# %%
with open("ACT_Python_Test.txt",'r') as file:
    data = file.read()
    print(data)
data=66
print(data)
# Out:
# This will add this line0
# This will add this line1
# This will add this line2
# This will add this line3
# This will add this line4
# 66

# %% [markdown]
# # **split() and readlines()**
#
#
#
# ```
# # Python code to illustrate split() function
# with open("file.text", "r") as file:
# 	data = file.readlines()
# 	for line in data:
# 		word = line.split()
# 		print (word)
#
# ```

# %%
#,encoding="utf-8" هذه للتعامل مع الاحرف الغير انجليزية من مثل العربي
with open("ACT_Python_Test.txt",'r',encoding="utf-8") as file:
    data = file.readlines()
    for line in data:#فور كل سطر في الداتا
        #print ([word for word in words if "جيد" in word])
        words = line.split()
        for word in words:#فور كل كلمة في السطر
          if "جيد" in word:#اذا الكلمة جيد موجوة 
            print (word)#أمر طباعة
    #print(data)
# Out:
# جيد
# جيد
# جيد

# %%
with open("ACT_Python_Test.txt",'r',encoding="utf-8") as file:
    data = file.readlines()#حولنا كل الداتا لاسكر في ليستة
    counter=0
    for line in data:#فور كل سطر 
        words = line.split()
        counter+=len(words)
    print(f"عدد الكلمات في النص هو {counter}")
# Out:
# عدد الكلمات في النص هو 21

# %% [markdown]
# # **واجب**
# اصنع سكريبت يقوم بالتالي باستخدام الدالة `While`
#
#
# 1.   ادخال بيانات الطلاب (اسم أول و اسم أخير و المادة و العلامة)
# 2.   خزن اسماء و علامات الطلاب في ملف
# 3. شرط التوقف هو ادخال (-1)

# %%
while True:
  with open("Homework.txt",'a',encoding="utf-8") as file:
    print("أدخل -1 لايقاف البرنامج")
    f =  input(" أدخل الاسم الأول ") 
    if f == "-1": 
       break
    l =  input(" أدخل الاسم الأخير ") 
    if l == "-1": 
       break
    c =  input(" أدخل المادة ") 
    if c == "-1": 
       break
    m =  input(" أدخل العلامة ") 
    if m == "-1": 
       break
    file.write(f"\nالإسم الأول هو {f} والاسم الاخير هو {l} و المادة هي {c} و العلامة هي {m}")
# Out:
# أدخل -1 لايقاف البرنامج
#  أدخل الاسم الأول 33
#  أدخل الاسم الأخير 33
#  أدخل المادة 33
#  أدخل العلامة 33
# أدخل -1 لايقاف البرنامج
#  أدخل الاسم الأول -1
