# %% [markdown]
# الكود الي احنا هنشوفه تحت بطبع اسمي
# ![1516850464968.jpg](data:image/jpeg;base64,...)

# %%
print("أنا اسمي محمود")
# Out:
# أنا اسمي محمود

# %%
name = "محمود"
print(name)
# Out:
# محمود

# %%
name = "Mahmoud A. M. SAmmour"
print(name)
# Out:
# Mahmoud A. M. SAmmour

# %%
i = True
i =False

# %%
number1 = 9
number2 = 4
number4 = 15.5

number3 = number1 + number2
print(number3)
# Out:
# 13

# %%
number3 = number1 - number2
print(number3)
# Out:
# 6

# %%
number3 = number1 * number2
print(number3)
# Out:
# 27

# %%
number3 = number1 / number2
print(number3)
# Out:
# 3.0

# %%
number3 = number1 % number2
print(number3)
# Out:
# 1

# %%
#الرقم الي على اليسار يساوي الرقم نفسه مع المعملة الرياضة في الرقم الي على اليمين
number3 = 1
number3 += 5 # واحد تساوي واحد + خمسة
print(number3)
# Out:
# 6

# %%
number3 = 2
number3 *= 5
print(number3)
# Out:
# 10

# %%
#the power of الاس
a = 4**2
print(a)
# Out:
# 1024

# %%
15number # منوع نبدأ اسم المتغير برقم
# Out:
#   File "<ipython-input-37-547c392c6fcb>", line 1
#     15number
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# frjba';sddgsdf
# sdfg
# sdf
# g
# sdfg
# sdfانا برمجة فقرة أ و باقيلي باقي الفقرات و روح اتذكرها من صفجة
#
# g

# %%
15=20 # ممنوع المتغير يكون رقم فقط
# Out:
#   File "<ipython-input-38-5fba23616794>", line 1
#     15=20 # ممنوع المتغير يكون رقم فقط
#                                       ^
# SyntaxError: can't assign to literal

# %%
Number = 1

# %%
NUMBER = 1

# %%
numberOneIsTwo
firstName
lastName
